# %% [markdown]
# **1(i) Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L. Print L.**

# %%
roll_no = "1024170423"

L = [int(digit) * 10 for digit in roll_no]

print(L)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 40, 20, 30]

# %% [markdown]
# 1(ii) **Add two numbers of your choice to L — one using append() and one using insert() at a specific position. Print L after each and explain in a comment what changed.**

# %%
L.append(100)
print(L)

L.insert(2, 200)
print(L)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 40, 20, 30, 100]
# [10, 0, 200, 20, 40, 10, 70, 0, 40, 20, 30, 100]

# %% [markdown]
# 1(iii) **Remove two elements from L — one using remove() and one using pop(). Print L after each.**

# %%
L.remove(100)
print(L)

L.pop(2)
print(L)
# Out:
# [10, 0, 200, 20, 40, 10, 70, 0, 40, 20, 30]
# [10, 0, 20, 40, 10, 70, 0, 40, 20, 30]

# %% [markdown]
# 1(iv)**Sort L in ascending order using sort(), then descending order using sort(reverse=True). Print both.**

# %%
L.sort()
print(L)
L.sort(reverse=True)
print(L)
# Out:
# [0, 0, 10, 10, 20, 20, 30, 40, 40, 70]
# [70, 40, 40, 30, 20, 20, 10, 10, 0, 0]

# %% [markdown]
#  Use slicing to print the first three elements and the last three elements of L in a single line each.

# %%
print(L[:3])
print(L[-3:])
# Out:
# [70, 40, 40]
# [10, 0, 0]

# %% [markdown]
# 1(vi) **Use list comprehension to create a new list containing only the elements of L that are greater than the average of L.**

# %%
average = sum(L) / len(L)
new_list = [x for x in L if x > average]
print(new_list)
# Out:
# [70, 40, 40, 30]

# %% [markdown]
# #2. Create a tuple named scores containing 8 marks using the first 8 values from L.

# %%
scores = tuple(L[:8])
print(scores)
# Out:
# (70, 40, 40, 30, 20, 20, 10, 10)

# %% [markdown]
# **2(i) Find the highest score and its index, and the lowest score and how many times it appears.**

# %%
highest = max(scores)
highest_index = scores.index(highest)
lowest = min(scores)
lowest_count = scores.count(lowest)
print("Highest score:", highest)
print("Index of highest score:", highest_index)
print("Lowest score:", lowest)
print("Lowest score appears:", lowest_count, "time(s)")
# Out:
# Highest score: 70
# Index of highest score: 0
# Lowest score: 10
# Lowest score appears: 2 time(s)

# %% [markdown]
# **2(ii). Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place — explain why in a one-line comment, referring to tuple immutability).**

# %%
reversed_list = list(scores[::-1])
# Tuple cannot be reversed in place because tuples are immutable and cannot be modified after creation
print(reversed_list)
# Out:
# [10, 10, 20, 20, 30, 40, 40, 70]

# %% [markdown]
# **2(iii). Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present message if not.**

# %%
score = int(input("Enter a score: "))
if score in scores:
    print("first occurance:", scores.index(score))
else:
    print("Score is not present in the tuple")
# Out:
# Enter a score: 20
# first occurance: 4

# %% [markdown]
# **2(iv). Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error Python raises, and explain in one line why this happens and how it differs from a list.**

# %%
scores[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1137/1957282536.py in <cell line: 0>()
# ----> 1 scores[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
#  Tuple elements cannot be changed because tuples are immutable, while lists allow modification of elements.

# %% [markdown]
# 2(v).**Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a single line of unpacking.**

# %%
first, second, *remaining = scores
print(first)
print(second)
print(remaining)
# Out:
# 70
# 40
# [40, 30, 20, 20, 10, 10]

# %% [markdown]
# #3. Set the random seed to your own roll number

# %%
import random
random.seed(1024170423)
numbers = [random.randint(100, 900) for i in range(100)]
print(numbers)
# Out:
# [251, 871, 448, 513, 115, 818, 399, 324, 297, 620, 257, 422, 834, 862, 374, 824, 796, 566, 312, 748, 432, 150, 359, 709, 469, 587, 359, 104, 799, 341, 529, 153, 680, 152, 794, 316, 415, 153, 587, 642, 887, 448, 143, 469, 299, 861, 372, 737, 883, 695, 737, 531, 710, 307, 861, 136, 283, 609, 187, 334, 742, 308, 392, 418, 559, 229, 612, 207, 826, 107, 116, 353, 382, 207, 888, 611, 636, 520, 669, 254, 156, 624, 685, 641, 121, 481, 899, 462, 474, 396, 271, 878, 841, 715, 209, 467, 276, 120, 200, 599]

# %% [markdown]
# **3(i). Generate a list of 100 random numbers between 100 and 900 (inclusive). Count and print all odd numbers in the list.**

# %%
odd_numbers = [x for x in numbers if x % 2 != 0]
print("Odd numbers:", odd_numbers)
print("Count of odd numbers:", len(odd_numbers))
# Out:
# Odd numbers: [251, 871, 513, 115, 399, 297, 257, 359, 709, 469, 587, 359, 799, 341, 529, 153, 415, 153, 587, 887, 143, 469, 299, 861, 737, 883, 695, 737, 531, 307, 861, 283, 609, 187, 559, 229, 207, 107, 353, 207, 611, 669, 685, 641, 121, 481, 899, 271, 841, 715, 209, 467, 599]
# Count of odd numbers: 53

# %% [markdown]
# **3(ii). Count and print all even numbers in the list.**

# %%
even_numbers = [x for x in numbers if x % 2 == 0]
print("Even numbers:", even_numbers)
print("Count of even numbers:", len(even_numbers))
# Out:
# Even numbers: [448, 818, 324, 620, 422, 834, 862, 374, 824, 796, 566, 312, 748, 432, 150, 104, 680, 152, 794, 316, 642, 448, 372, 710, 136, 334, 742, 308, 392, 418, 612, 826, 116, 382, 888, 636, 520, 254, 156, 624, 462, 474, 396, 878, 276, 120, 200]
# Count of even numbers: 47

# %% [markdown]
# **3(iii). Count and print all prime numbers in the list, and additionally build the actual list of prime numbers found using list comprehension.**

# %%
def is_prime(n):
    if n < 2:
        return False

    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True
prime_numbers = [x for x in numbers if is_prime(x)]
print("Prime numbers:", prime_numbers)
print("Count of prime numbers:", len(prime_numbers))
# Out:
# Prime numbers: [251, 257, 359, 709, 587, 359, 587, 887, 883, 307, 283, 229, 107, 353, 641, 271, 467, 599]
# Count of prime numbers: 18

# %% [markdown]
# **3(iv). Print the number that occurs most frequently in your list, and how many times it occurs.**

# %%
frequency = {}
for x in numbers:
    frequency[x] = numbers.count(x)
most_frequent = max(frequency, key=frequency.get)
print("Most frequent number:", most_frequent)
print("Occurrences:", frequency[most_frequent])
# Out:
# Most frequent number: 448
# Occurrences: 2

# %% [markdown]
# #4 Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for each digit} and set B = {digit × 9 for each digit}. Print both sets.

# %%
digits = [1, 0, 2, 4, 1, 7, 0, 4]
A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}
print("Set A:", A)
print("Set B:", B)
# Out:
# Set A: {0, 7, 14, 49, 28}
# Set B: {0, 36, 9, 18, 63}

# %% [markdown]
# **4(vi). Find the union of A and B — all unique values across both sets.**

# %%
union_set = A.union(B)
print("Union:", union_set)
# Out:
# Union: {0, 36, 7, 9, 14, 49, 18, 28, 63}

# %% [markdown]
# **4(vii). Find the intersection of A and B — values common to both.**

# %%
intersection_set = A.intersection(B)
print("Intersection:", intersection_set)
# Out:
# Intersection: {0}

# %% [markdown]
# **4(viii). Find A − B and B − A separately using difference(), and explain in one line how this differs from symmetric_difference().**

# %%
A_difference_B = A.difference(B)
B_difference_A = B.difference(A)
print("A - B:", A_difference_B)
print("B - A:", B_difference_A)
# Out:
# A - B: {49, 28, 14, 7}
# B - A: {9, 18, 36, 63}

# %% [markdown]
# difference() returns values present only in one set like it gives A value in A-B, while symmetric_difference() removes the common elements

# %% [markdown]
# **4(ix). Find the symmetric difference of A and B.**

# %%
symmetric_difference = A.symmetric_difference(B)
print("Symmetric Difference:", symmetric_difference)
# Out:
# Symmetric Difference: {7, 9, 14, 18, 28, 36, 49, 63}

# %% [markdown]
# **4(x). Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset().**

# %%
print("A is subset of B:", A.issubset(B))
print("B is superset of A:", B.issuperset(A))
# Out:
# A is subset of B: False
# B is superset of A: False

# %% [markdown]
# **4(xi). Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain in one line why discard() is safer than remove() when you're not sure the value exists.**

# %%
X = int(input("Enter value to remove from A: "))
A.discard(X)
print("Set A after removal:", A)
# Out:
# Enter value to remove from A: 63
# Set A after removal: {0, 7, 14, 49, 28}

# %% [markdown]
# discard() is safer than remove() because it does not give an error if the element is not present in the set.

# %% [markdown]
# #5. Consider the following dictionary:

# %%
my_dict = {
    "name": "Ashirwad Khatri",
    "roll_no": "1024170423",
    "branch": "COPC",
    "age": 19,
    "city": "Patiala"
}
print(my_dict)
# Out:
# {'name': 'Ashirwad Khatri', 'roll_no': '1024170423', 'branch': 'COPC', 'age': 19, 'city': 'Patiala'}

# %% [markdown]
# **5(i). Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by hand — use pop() or dictionary comprehension so the code would work for any dictionary).**

# %%
my_dict["location"] = my_dict.pop("city")
print(my_dict)
# Out:
# {'name': 'Ashirwad Khatri', 'roll_no': '1024170423', 'branch': 'COPC', 'age': 19, 'location': 'Patiala'}

# %% [markdown]
# **(ii). Add a new key “cgpa” with your CGPA as its value.**

# %%
my_dict["cgpa"] = 8.5
print(my_dict)
# Out:
# {'name': 'Ashirwad Khatri', 'roll_no': '1024170423', 'branch': 'COPC', 'age': 19, 'location': 'Patiala', 'cgpa': 8.5}

# %% [markdown]
# **5(iii). Update the value of “age” by increasing it by 1.**

# %%
my_dict["age"] = my_dict["age"] + 1
print(my_dict)
# Out:
# {'name': 'Ashirwad Khatri', 'roll_no': '1024170423', 'branch': 'COPC', 'age': 20, 'location': 'Patiala', 'cgpa': 8.5}

# %% [markdown]
# **5(iv). Delete the “branch” key using two different methods in two separate copies of the dictionary: once with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what does each return?).
#
# Using pop()**

# %%
dict_pop = my_dict.copy()
removed_value = dict_pop.pop("branch")
print(dict_pop)
print("Removed value:", removed_value)
# Out:
# {'name': 'Ashirwad Khatri', 'roll_no': '1024170423', 'age': 20, 'location': 'Patiala', 'cgpa': 8.5}
# Removed value: COPC

# %% [markdown]
# pop() removes the key and returns its value, so the deleted value can be stored.

# %% [markdown]
# **Using del**

# %%
dict_del = my_dict.copy()
del dict_del["branch"]
print(dict_del)
# Out:
# {'name': 'Ashirwad Khatri', 'roll_no': '1024170423', 'age': 20, 'location': 'Patiala', 'cgpa': 8.5}

# %% [markdown]
# del deletes the key directly but does not return the removed value.

# %% [markdown]
# 5(v). **Iterate over your dictionary using .items() and print each key-value pair as “key → value”.**

# %%
for key, value in my_dict.items():
    print(key, "→", value)
# Out:
# name → Ashirwad Khatri
# roll_no → 1024170423
# branch → COPC
# age → 20
# location → Patiala
# cgpa → 8.5

# %% [markdown]
# 5(vi). **Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence using the in keyword and print a safe fallback message instead of letting the program crash.**

# %%
if "email" in my_dict:
    print(my_dict["email"])
else:
    print("Email key does not exist")
# Out:
# Email key does not exist

# %% [markdown]
# **(vii). Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details. Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win” when both dictionaries share a key.**

# %%
friend_dict = {
    "name": "Rahul Sharma",
    "roll_no": "1024000000",
    "branch": "ECE",
    "age": 20,
    "city": "Mumbai"
}
merged_dict = {**my_dict, **friend_dict}
print(merged_dict)
# Out:
# {'name': 'Rahul Sharma', 'roll_no': '1024000000', 'branch': 'ECE', 'age': 20, 'location': 'Patiala', 'cgpa': 8.5, 'city': 'Mumbai'}

# %% [markdown]
# {**dict1, **dict2} combines dictionaries. If both have the same key, the value from the second dictionary (friend_dict) replaces the first one.

# %% [markdown]
# **5(viii). Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your original dictionary where the value is a string.**

# %%
string_dict = {key: value for key, value in my_dict.items() if isinstance(value, str)}
print(string_dict)
# Out:
# {'name': 'Ashirwad Khatri', 'roll_no': '1024170423', 'branch': 'COPC', 'location': 'Patiala'}
